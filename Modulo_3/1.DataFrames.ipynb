# %% [markdown]
# # Introducción basica a pandas

# %% [markdown]
# Pandas es un paquete open-source que nos proporciona una forma sencilla y potente de trabajar con  estructura de datos a través de múltiples herramientas para su análisis

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# En pandas existen dos tipos de estructuras basicas:
#
# - Series
# - Dataframes

# %% [markdown]
# ## Series

# %% [markdown]
# Una series es un arreglo en el que cada valor tiene asignado una etiqueta (índice) y ademas admite un título (nombre)

# %%
data = {'Apple': 147000,
'Samsung': 267937,
'Google': 135301,
'Microsoft': 163000,
'Huawei': 197000,
'Dell': 158000,
'Facebook': 58604,
'Foxconn': 878429,
'Sony': 109700}

# %% [markdown]
# ## Sleccionando usando indexado numérico

# %% [markdown]
# ## Selección usando etiquetas

# %% [markdown]
# ## Fragmentos de comienzo y fin

# %% [markdown]
# ## Podemos realizar operaciones con series

# %% [markdown]
# ## Ordenar

# %% [markdown]
# ## Funciones estadísticas

# %% [markdown]
# # DataFrames

# %% [markdown]
# Un DataFrame es una estructura tabular compuesta por series. Se trata del tipo de datos fundamental en pandas y sobre el que giran la mayoría de operaciones que podemos realizar.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
employees = pd.Series({
    'Apple': 147000,
    'Samsung': 267937,
    'Google': 135301,
    'Microsoft': 163000,
    'Huawei': 197000,
    'Dell': 158000,
    'Facebook': 58604,
    'Foxconn': 878429,
    'Sony': 109700
}, name='employees')

revenues = pd.Series({
    'Apple': 274515,
    'Samsung': 200734,
    'Google': 182527,
    'Microsoft': 143015,
    'Huawei': 129184,
    'Dell': 92224,
    'Facebook': 85965,
    'Foxconn': 181945,
    'Sony': 84893
}, name='revenues')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
